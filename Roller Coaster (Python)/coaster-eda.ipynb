# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### In this project, I will perform exploratory data analysis on coaster dataset.

# %% [markdown]
# ### 0. Importing packages and dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
#pd.set_option('max_columns', 200)

# %%
df = pd.read_csv("/kaggle/input/rollercoaster/coaster_db.csv")
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %% [markdown]
# ### 1. Understanding the data

# %% [markdown]
# Checking number of rows and columns.

# %%
df.shape
# Out:
# (1087, 56)

# %% [markdown]
# Checking type od data

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %% [markdown]
# Performing basic statistical calculations on numerical columns.

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ### 2. Data preparation & cleaning

# %% [markdown]
# This dataset has too much columns. In this analysis, I will not need all of them, therefore, I will keep only those columns that are interesting for analysis.

# %%
df = df[['coaster_name',
    # 'Length', 'Speed',
    'Location', 'Status',
    # 'Opening date',
    #   'Type',
    'Manufacturer',
#     'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date',
#     'Opened', 
    # 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
        'latitude', 'longitude',
    'Type_Main',
       'opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit',
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %% [markdown]
# I will change opening_date_clean to date data type.

# %%
pd.to_datetime(df['opening_date_clean'])
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %% [markdown]
# I will rename columns, in order to be standardized.

# %%
df=df.rename(columns={'coaster_name': "Coaster_Name",
                   'year_introduced': "Year_Introduced",
                  'latitude':"Latitude", 'longitude':"Longitude",
                  'opening_date_clean':"Opening_Date", 'speed_mph':"Speed_mph",
                  'height_ft':"Height_ft", 'Inversions_clean':"Inversions",'Gforce_clean':"Gforce"})

# %% [markdown]
# Checking null values inside new dataset.

# %%
df.isnull().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# Latitude           275
# Longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_mph          150
# Height_ft          916
# Inversions           0
# Gforce             725
# dtype: int64

# %% [markdown]
# Checking duplicates.

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
# Checking an example duplicate
df.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed_mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_ft  Inversions  Gforce
# 39        NaN           0     4.0
# 43        NaN           0     4.0

# %%
# Removing duplicates
df = df.loc[~df.duplicated(subset=['Coaster_Name','Location', 'Opening_Date'])]\
    .reset_index(drop=True).copy()

# %% [markdown]
# ### 3. Understanding the feature

# %% [markdown]
# #### Grouping data by the year introduced and showing graphically.

# %%
graph1 = df['Year_Introduced'].value_counts() \
.head(10) \
.plot(kind='bar', title='Top 10 Years Coasters Introduced')
graph1.set_xlabel('Year Introduced')
graph1.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Plotting histogram

# %%
graph2 = df['Speed_mph'].plot(kind='hist', bins=20, title="Coaster Speed (mph)")
graph2.set_xlabel('Speed')
plt.show()

# %% [markdown]
# ### 4. Relationship between features

# %% [markdown]
# #### Creating scatterplot using matplotlib

# %%
df.plot(kind='scatter', x='Speed_mph', y='Height_ft', title='Coaster speed vs. Height')
plt.show()

# %% [markdown]
# #### Creating scatterplot using seaborn

# %%
sns.scatterplot(x='Speed_mph', y='Height_ft', hue='Year_Introduced', data=df)
plt.show()

# %% [markdown]
# #### Creating pairplot

# %%
sns.pairplot(data=df, vars=['Year_Introduced','Speed_mph','Height_ft','Inversions','Gforce'], hue='Type_Main')
plt.show()

# %% [markdown]
# #### Looking for correlation

# %%
df_corr=df.drop(columns=['Latitude','Longitude']).corr(numeric_only=True)
df_corr
# Out:
#                  Year_Introduced  Speed_mph  Height_ft  Inversions    Gforce
# Year_Introduced         1.000000   0.225991   0.249487    0.233701 -0.073403
# Speed_mph               0.225991   1.000000   0.823216    0.246593  0.503828
# Height_ft               0.249487   0.823216   1.000000    0.138286  0.480465
# Inversions              0.233701   0.246593   0.138286    1.000000  0.339137
# Gforce                 -0.073403   0.503828   0.480465    0.339137  1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 5. Ask a Question about the data

# %% [markdown]
# What are the locations with the fastest roller coasters (minimum 10)?

# %%
ax=df.query('Location != "Other"') \
.groupby('Location')['Speed_mph'] \
.agg(['mean','count']) \
.query('count >= 10') \
.sort_values('mean')['mean'] \
.plot(kind='barh', figsize=(12,5), title='Average Coaster Speed by Location')
ax.set_xlabel('Average Coaster Speed')
plt.show()
